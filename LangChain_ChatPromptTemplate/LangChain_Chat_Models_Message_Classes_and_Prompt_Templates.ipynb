# %%
# !pip install -q langchain-google-genai langchain
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/72.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.7/561.7 kB 34.4 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage,SystemMessage
from IPython.display import Markdown, display

# %%
llm=ChatGoogleGenerativeAI(api_key="api key"
,model="gemini-3-flash-preview")

# %%
prompt=PromptTemplate.from_template("give me the list of post paid jobs in{country}")

# %%
country=input("enter the country")
# Out:
# enter the countryindia

# %%
text=prompt.format(country=country)

# %%
message=[SystemMessage(content="you are a helpful assistant"),HumanMessage(content=text)]

# %%
response=llm.invoke(message)

# %%
display(Markdown(response.text))
# Out:
# The term "post-paid jobs" is not a standard recruitment term, but it usually refers to one of three things in the Indian context:
#
# 1.  **Commission-based jobs:** You get paid after you make a sale or complete a target.
# 2.  **Gig/Freelance work:** You get paid after a specific task or project is submitted.
# 3.  **Pay After Placement (PAP) models:** These are training programs where you learn for free and pay the tuition fee only after you get a job.
#
# Here is a list of jobs in India that follow these "payment after work" models:
#
# ### 1. Sales and Commission-Based Roles
# In these roles, your primary income comes from incentives or a "success fee" after the deal is closed.
# *   **Insurance Agents:** (LIC, HDFC Life, ICICI Prudential). You earn a percentage of the premium after the policy is sold.
# *   **Real Estate Agents/Brokers:** You earn a commission (usually 1-2%) after a property is bought, sold, or rented.
# ...

# %%
prompt2=PromptTemplate.from_template("interview questions on this {subject}")

# %%
topic=input("enter the subject you want to prepare")
# Out:
# enter the subject you want to preparegenai

# %%
text=prompt2.format(subject=topic)

# %%
message2=[SystemMessage(content="you are a helpful assistant"),HumanMessage(content=text)]

# %%
response2=llm.invoke(message2)

# %%
display(Markdown(response2.text))
# Out:
# Generative AI (GenAI) is a broad field, so interview questions can range from high-level conceptual questions to deep technical architecture discussions.
#
# Here are the top GenAI interview questions categorized by difficulty and topic:
#
# ---
#
# ### 1. Conceptual & Fundamental Questions
# *These are common for Product Managers, Data Analysts, or entry-level Engineers.*
#
# *   **What is the fundamental difference between Discriminative and Generative AI?**
#     *   *Answer:* Discriminative models learn the boundary between classes (e.g., "is this a cat or a dog?"). Generative models learn the distribution of the data to create new instances (e.g., "generate an image of a cat").
# *   **What is a Large Language Model (LLM)?**
#     *   *Answer:* An LLM is a type of AI trained on massive amounts of text data using deep learning (usually Transformer architecture) to understand, summarize, and generate human-like text.
# ...
